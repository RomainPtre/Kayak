# %% [markdown]
# # Your job will be to:
#
# Scrape data from destinations
#
# Get weather data from each destination
#
# Get hotels' info about each destination
#
# Store all the information above in a data lake
#
# Extract, transform and load cleaned data from your datalake to a data warehouse

# %%
import pandas as pd
import requests
import logging
from scrapy.crawler import CrawlerProcess
import os 
import scrapy
import re

# %%
destinations = ["Mont Saint Michel",
"St Malo",
"Bayeux",
"Le Havre",
"Rouen",
"Paris",
"Amiens",
"Lille",
"Strasbourg",
"Chateau du Haut Koenigsbourg",
"Colmar",
"Eguisheim",
"Besancon",
"Dijon",
"Annecy",
"Grenoble",
"Lyon",
"Gorges du Verdon",
"Bormes les Mimosas",
"Cassis",
"Marseille",
"Aix en Provence",
"Avignon",
"Uzes",
"Nimes",
"Aigues Mortes",
"Saintes Maries de la mer",
"Collioure",
"Carcassonne",
"Ariege",
"Toulouse",
"Montauban",
"Biarritz",
"Bayonne",
"La Rochelle"]

# %%
## Endpoint
# https://nominatim.openstreetmap.org/search?<params>

# %%
# # Get the url and check that it returns a success code
# url = 'https://nominatim.openstreetmap.org/search'
# r = requests.get(url)
# r

# %%
'''From the API documentation, 'city' should be used to call at the endpoint to search for a specific city, and should return a jsonv2 by default'''

'https://nominatim.org/release-docs/develop/api/Search/#structured-query'
# Out:
# 'https://nominatim.org/release-docs/develop/api/Search/#structured-query'

# %% [markdown]
# # First, I am testing it for one city

# %%
# Test with html url

# paris=requests.get('https://nominatim.openstreetmap.org/ui/search.html?city=Paris')
# paris

# %%
# paris.content

# %%
# ## Test with manual url
# # here it is working

# paris=requests.get('https://nominatim.openstreetmap.org/search?city=Paris&country=France&format=json')
# paris

# %%
# paris.content

# %%
# it is working ! Carefull, I have been banned before because I forgot to add headers (User-Agent at least) : Error 403
# to know user-agent, go in dev mode in the browser, network tab and type navigator.userAgent in the console
# can add 'From' : 'email address' in the headers too if needed (for heavy usage)
## Important to add the 'country=France' param because other Paris in the world. ALSO ADD limit = 1 because the request returns several results for the same city
headers = {'User-Agent' : 'Chrome/125.0.0.0'}
payload = {'city':'Paris', 'country':'France', 'format':'json', 'limit' : '1'}

paris=requests.get('https://nominatim.openstreetmap.org/search', headers=headers, params=payload)
print('Code is {}'.format(paris))
print(paris.content)
# Out:
# Code is <Response [200]>
# b'[{"place_id":82297359,"licence":"Data \xc2\xa9 OpenStreetMap contributors, ODbL 1.0. http://osm.org/copyright","osm_type":"relation","osm_id":71525,"lat":"48.8534951","lon":"2.3483915","class":"boundary","type":"administrative","place_rank":12,"importance":0.8317101715588673,"addresstype":"city","name":"Paris","display_name":"Paris, \xc3\x8ele-de-France, France m\xc3\xa9tropolitaine, France","boundingbox":["48.8155755","48.9021560","2.2241220","2.4697602"]}]'

# %%
# transform the output as a list
paris=list(paris.json())

# %%
type(paris)
# Out:
# list

# %%
#check the output, coordinates are correct
paris
# Out:
# [{'place_id': 83293737,
#   'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. http://osm.org/copyright',
#   'osm_type': 'relation',
#   'osm_id': 71525,
#   'lat': '48.8534951',
#   'lon': '2.3483915',
#   'class': 'boundary',
#   'type': 'administrative',
#   'place_rank': 12,
#   'importance': 0.8317101715588673,
#   'addresstype': 'city',
#   'name': 'Paris',
#   'display_name': 'Paris, Île-de-France, France métropolitaine, France',
#   'boundingbox': ['48.8155755', '48.9021560', '2.2241220', '2.4697602']}]

# %%
#create a dataframe
paris_df=pd.DataFrame(paris)
paris_df
# Out:
#    place_id                                            licence  osm_type  \
# 0  83293737  Data © OpenStreetMap contributors, ODbL 1.0. h...  relation
#
#    osm_id         lat        lon     class            type  place_rank  \
# 0   71525  48.8534951  2.3483915  boundary  administrative          12
#
#    importance addresstype   name  \
# 0     0.83171        city  Paris
#
#                                         display_name  \
# 0  Paris, Île-de-France, France métropolitaine, F...
#
#                                       boundingbox
# 0  [48.8155755, 48.9021560, 2.2241220, 2.4697602]

# %%
#Trim the dataframe to keep only the data of interest
paris_df_trim=paris_df[['place_id', 'lat', 'lon', 'name']]
paris_df_trim
# Out:
#    place_id         lat        lon   name
# 0  83293737  48.8534951  2.3483915  Paris

# %% [markdown]
# Quand on passe à l'iteration, mettre un param qui bloque un peu la boulcvep our laisser l'API se regenerer (time_sleep ? await? un truc du genre)
#
# Essaye vaec une liste navec que 3 villes pour eviter de se faire ban

# %% [markdown]
# # Nouvel essai en iterations cette fois-ci, avec seulement 3 villes

# %%
destinations_backup=destinations

# %%
#space should be replaced by + in params
destinations= [city.replace(' ', '+') for city in destinations]
destinations
# Out:
# ['Mont+Saint+Michel',
#  'St+Malo',
#  'Bayeux',
#  'Le+Havre',
#  'Rouen',
#  'Paris',
#  'Amiens',
#  'Lille',
#  'Strasbourg',
#  'Chateau+du+Haut+Koenigsbourg',
#  'Colmar',
#  'Eguisheim',
#  'Besancon',
#  'Dijon',
#  'Annecy',
#  'Grenoble',
#  'Lyon',
#  'Gorges+du+Verdon',
#  'Bormes+les+Mimosas',
#  'Cassis',
#  'Marseille',
#  'Aix+en+Provence',
#  'Avignon',
#  'Uzes',
#  'Nimes',
#  'Aigues+Mortes',
#  'Saintes+Maries+de+la+mer',
#  'Collioure',
#  'Carcassonne',
#  'Ariege',
#  'Toulouse',
#  'Montauban',
#  'Biarritz',
#  'Bayonne',
#  'La+Rochelle']

# %%
len(destinations)
# Out:
# 34

# %%
destinations_trim=destinations[:3]
destinations_trim
# Out:
# ['Mont+Saint+Michel', 'St+Malo', 'Bayeux']

# %%
type(destinations_trim)
# Out:
# list

# %%
#Do it with one city to initiate the dataframe
headers = {'User-Agent' : 'Chrome/125.0.0.0'}
payload = {'city':'{}'.format(destinations_trim[0]), 'country':'France', 'format':'json', 'limit' : '1'}

response=requests.get('https://nominatim.openstreetmap.org/search', headers=headers, params=payload)
print('Code is {}'.format(response))
city_trim_df=pd.DataFrame(response.json())
city_trim_df
# Out:
# Code is <Response [200]>
#     place_id                                            licence osm_type  \
# 0  276970680  Data © OpenStreetMap contributors, ODbL 1.0. h...      way
#
#       osm_id         lat                 lon  class   type  place_rank  \
# 0  211285890  48.6359541  -1.511459954959514  place  islet          20
#
#    importance addresstype               name  \
# 0    0.455437       islet  Mont Saint-Michel
#
#                                         display_name  \
# 0  Mont Saint-Michel, Le Mont-Saint-Michel, Avran...
#
#                                         boundingbox
# 0  [48.6349172, 48.6370310, -1.5133292, -1.5094796]

# %%
#Drop the first destination because we already scrapped its data when initiating the dataframe
destinations_trim.pop(0)
destinations_trim
# Out:
# ['St+Malo', 'Bayeux']

# %%
#Run the loop for the rest of the destinations; ignore_index=true in pd.concat otherwise all index rows are 0
headers = {'User-Agent' : 'Chrome/125.0.0.0'}

for city in range(len(destinations_trim)):
    payload = {'city':'{}'.format(destinations_trim[city]), 'country':'France', 'format':'json', 'limit' : '1'}
    response=requests.get('https://nominatim.openstreetmap.org/search', headers=headers, params=payload)
    city_trim_df=pd.concat([city_trim_df, pd.DataFrame(response.json())], ignore_index=True)
city_trim_df
# Out:
#     place_id                                            licence  osm_type  \
# 0  276970680  Data © OpenStreetMap contributors, ODbL 1.0. h...       way
# 1  277106181  Data © OpenStreetMap contributors, ODbL 1.0. h...  relation
# 2  276101915  Data © OpenStreetMap contributors, ODbL 1.0. h...  relation
#
#       osm_id         lat                 lon     class            type  \
# 0  211285890  48.6359541  -1.511459954959514     place           islet
# 1     905534   48.649518          -2.0260409  boundary  administrative
# 2     145776  49.2764624          -0.7024738  boundary  administrative
#
#    place_rank  importance addresstype               name  \
# 0          20    0.455437       islet  Mont Saint-Michel
# 1          16    0.576467        town         Saint-Malo
# 2          16    0.572700        town             Bayeux
#
#                                         display_name  \
# 0  Mont Saint-Michel, Le Mont-Saint-Michel, Avran...
# 1  Saint-Malo, Ille-et-Vilaine, Bretagne, France ...
# 2  Bayeux, Calvados, Normandie, France métropolit...
#
#                                         boundingbox
# 0  [48.6349172, 48.6370310, -1.5133292, -1.5094796]
# 1  [48.5979853, 48.6949736, -2.0765246, -1.9367259]
# 2  [49.2608124, 49.2934736, -0.7275671, -0.6757378]

# %%
#Trim the dataframe to keep only the data of interest
city_df_trim=city_trim_df[['place_id', 'lat', 'lon', 'name']]
city_df_trim
# Out:
#     place_id         lat                 lon               name
# 0  276970680  48.6359541  -1.511459954959514  Mont Saint-Michel
# 1  277106181   48.649518          -2.0260409         Saint-Malo
# 2  276101915  49.2764624          -0.7024738             Bayeux

# %%
#reorder columns order for readability
city_df_trim=city_df_trim[[ 'name', 'place_id', 'lat', 'lon']]
city_df_trim
# Out:
#                 name   place_id         lat                 lon
# 0  Mont Saint-Michel  276970680  48.6359541  -1.511459954959514
# 1         Saint-Malo  277106181   48.649518          -2.0260409
# 2             Bayeux  276101915  49.2764624          -0.7024738

# %% [markdown]
# # Final List of all destinations coordinates

# %%
#Do it with one city to initiate the dataframe
headers = {'User-Agent' : 'Chrome/125.0.0.0'}
payload = {'city':'{}'.format(destinations[0]), 'country':'France', 'format':'json', 'limit' : '1'}

response=requests.get('https://nominatim.openstreetmap.org/search', headers=headers, params=payload)
print('Code is {}'.format(response))
city_df=pd.DataFrame(response.json())
city_df
# Out:
# Code is <Response [200]>
#     place_id                                            licence osm_type  \
# 0  276970680  Data © OpenStreetMap contributors, ODbL 1.0. h...      way
#
#       osm_id         lat                 lon  class   type  place_rank  \
# 0  211285890  48.6359541  -1.511459954959514  place  islet          20
#
#    importance addresstype               name  \
# 0    0.455437       islet  Mont Saint-Michel
#
#                                         display_name  \
# 0  Mont Saint-Michel, Le Mont-Saint-Michel, Avran...
#
#                                         boundingbox
# 0  [48.6349172, 48.6370310, -1.5133292, -1.5094796]

# %%
#Drop the first destination because we already scrapped its data when initiating the dataframe
destinations.pop(0)
destinations
# Out:
# ['St+Malo',
#  'Bayeux',
#  'Le+Havre',
#  'Rouen',
#  'Paris',
#  'Amiens',
#  'Lille',
#  'Strasbourg',
#  'Chateau+du+Haut+Koenigsbourg',
#  'Colmar',
#  'Eguisheim',
#  'Besancon',
#  'Dijon',
#  'Annecy',
#  'Grenoble',
#  'Lyon',
#  'Gorges+du+Verdon',
#  'Bormes+les+Mimosas',
#  'Cassis',
#  'Marseille',
#  'Aix+en+Provence',
#  'Avignon',
#  'Uzes',
#  'Nimes',
#  'Aigues+Mortes',
#  'Saintes+Maries+de+la+mer',
#  'Collioure',
#  'Carcassonne',
#  'Ariege',
#  'Toulouse',
#  'Montauban',
#  'Biarritz',
#  'Bayonne',
#  'La+Rochelle']

# %%
#Run the loop for the rest of the destinations; ignore_index=true in pd.concat otherwise all index rows are 0
headers = {'User-Agent' : 'Chrome/125.0.0.0'}

for city in range(len(destinations)):
    payload = {'city':'{}'.format(destinations[city]), 'country':'France', 'format':'json', 'limit' : '1'}
    response=requests.get('https://nominatim.openstreetmap.org/search', headers=headers, params=payload)
    city_df=pd.concat([city_df, pd.DataFrame(response.json())], ignore_index=True)
city_df
# Out:
#      place_id                                            licence  osm_type  \
# 0   276970680  Data © OpenStreetMap contributors, ODbL 1.0. h...       way
# 1   277106181  Data © OpenStreetMap contributors, ODbL 1.0. h...  relation
# 2   276101915  Data © OpenStreetMap contributors, ODbL 1.0. h...  relation
# 3   116797886  Data © OpenStreetMap contributors, ODbL 1.0. h...  relation
# 4   116490697  Data © OpenStreetMap contributors, ODbL 1.0. h...  relation
# 5   114827617  Data © OpenStreetMap contributors, ODbL 1.0. h...  relation
# 6   116694242  Data © OpenStreetMap contributors, ODbL 1.0. h...  relation
# 7   118533424  Data © OpenStreetMap contributors, ODbL 1.0. h...  relation
# 8   381804960  Data © OpenStreetMap contributors, ODbL 1.0. h...  relation
# 9   136411398  Data © OpenStreetMap contributors, ODbL 1.0. h...      node
# 10  136331572  Data © OpenStreetMap contributors, ODbL 1.0. h...  relation
# 11  136516441  Data © OpenStreetMap contributors, ODbL 1.0. h...  relation
# 12  110217040  Data © OpenStreetMap contributors, ODbL 1.0. h...  relation
# 13  111540922  Data © OpenStreetMap contributors, ODbL 1.0. h...  relation
# 14  107354879  Data © OpenStreetMap contributors, ODbL 1.0. h...  relation
# 15  108194303  Data © OpenStreetMap contributors, ODbL 1.0. h...  relation
# 16  108560795  Data © OpenStreetMap contributors, ODbL 1.0. h...  relation
# 17  101828497  Data © OpenStreetMap contributors, ODbL 1.0. h...      node
# 18  101877567  Data © OpenStreetMap contributors, ODbL 1.0. h...  relation
# 19  102437647  Data © OpenStreetMap contributors, ODbL 1.0. h...  relation
# 20  387540349  Data © OpenStreetMap contributors, ODbL 1.0. h...  relation
# 21  102741999  Data © OpenStreetMap contributors, ODbL 1.0. h...  relation
# 22  102193665  Data © OpenStreetMap contributors, ODbL 1.0. h...  relation
# 23  106427400  Data © OpenStreetMap contributors, ODbL 1.0. h...  relation
# 24  102307633  Data © OpenStreetMap contributors, ODbL 1.0. h...  relation
# 25  102716851  Data © OpenStreetMap contributors, ODbL 1.0. h...  relation
# 26  102529062  Data © OpenStreetMap contributors, ODbL 1.0. h...  relation
# 27  103975931  Data © OpenStreetMap contributors, ODbL 1.0. h...  relation
# 28  104358485  Data © OpenStreetMap contributors, ODbL 1.0. h...  relation
# 29  103773365  Data © OpenStreetMap contributors, ODbL 1.0. h...  relation
# 30  376688237  Data © OpenStreetMap contributors, ODbL 1.0. h...  relation
# 31  105191250  Data © OpenStreetMap contributors, ODbL 1.0. h...  relation
# 32  283462568  Data © OpenStreetMap contributors, ODbL 1.0. h...  relation
# 33  281543649  Data © OpenStreetMap contributors, ODbL 1.0. h...  relation
# 34  280762466  Data © OpenStreetMap contributors, ODbL 1.0. h...  relation
#
#         osm_id         lat                 lon     class               type  \
# 0    211285890  48.6359541  -1.511459954959514     place              islet
# 1       905534   48.649518          -2.0260409  boundary     administrative
# 2       145776  49.2764624          -0.7024738  boundary     administrative
# 3       104492  49.4938975           0.1079732  boundary     administrative
# 4        75628  49.4404591           1.0939658  boundary     administrative
# 5        71525  48.8534951           2.3483915  boundary     administrative
# 6       114347  49.8941708           2.2956951  boundary     administrative
# 7        58404  50.6365654           3.0635282  boundary     administrative
# 8        71033   48.584614           7.7507127  boundary     administrative
# 9   4245068168  48.2495226           7.3454923     place  isolated_dwelling
# 10       61423  48.0777517           7.3579641  boundary     administrative
# 11       79442  48.0447968           7.3079618  boundary     administrative
# 12      103599  47.2380222           6.0243622  boundary     administrative
# 13       74090  47.3215806           5.0414701  boundary     administrative
# 14     6791758  45.8992348           6.1288847  boundary     administrative
# 15       80348  45.1875602           5.7357819  boundary     administrative
# 16      120965  45.7578137           4.8320114  boundary     administrative
# 17  7193513219  43.7496562           6.3285616   natural              gorge
# 18     1118915  43.1506968           6.3419285  boundary     administrative
# 19       76425  43.2140359           5.5396318  boundary     administrative
# 20       76469  43.2961743           5.3699525  boundary     administrative
# 21       70279  43.5298424           5.4474738  boundary     administrative
# 22      102478  43.9492493           4.8059012  boundary     administrative
# 23      380050  44.0121279           4.4196718  boundary     administrative
# 24      378685  43.8374249           4.3600687  boundary     administrative
# 25      272287  43.5661521             4.19154  boundary     administrative
# 26      414459  43.4515922           4.4277202  boundary     administrative
# 27       18409    42.52505           3.0831554  boundary     administrative
# 28       37774  43.2130358           2.3491069  boundary     administrative
# 29     1806623  42.8458016           1.6067586  boundary     administrative
# 30       35738  43.6044622           1.4442469  boundary     administrative
# 31      137735  44.0175835           1.3549991  boundary     administrative
# 32      166717  43.4832523          -1.5592776  boundary     administrative
# 33      166713  43.4945144          -1.4736657  boundary     administrative
# 34      117858  46.1591126          -1.1520434  boundary     administrative
#
#     place_rank  importance        addresstype                         name  \
# 0           20    0.455437              islet            Mont Saint-Michel
# 1           16    0.576467               town                   Saint-Malo
# 2           16    0.572700               town                       Bayeux
# 3           16    0.622333               city                     Le Havre
# 4           16    0.640073               city                        Rouen
# 5           12    0.831710               city                        Paris
# 6           16    0.624949               city                       Amiens
# 7           16    0.653204               city                        Lille
# 8           16    0.674805               city                   Strasbourg
# 9           22    0.106728  isolated_dwelling  Château du Haut-Kœnigsbourg
# 10          16    0.585296               town                       Colmar
# 11          16    0.524972            village                    Eguisheim
# 12          16    0.618351               city                     Besançon
# 13          16    0.633619               city                        Dijon
# 14          16    0.579077               city                       Annecy
# 15          16    0.641809               city                     Grenoble
# 16          16    0.691378               city                         Lyon
# 17          22    0.378150              gorge             Gorges du Verdon
# 18          16    0.477316            village           Bormes-les-Mimosas
# 19          16    0.476780            village                       Cassis
# 20          16    0.681377               city                    Marseille
# 21          16    0.591085               city              Aix-en-Provence
# 22          16    0.622094               city                      Avignon
# 23          16    0.537533            village                         Uzès
# 24          16    0.603055               city                        Nîmes
# 25          16    0.532380               town                Aigues-Mortes
# 26          16    0.472517               town     Saintes-Maries-de-la-Mer
# 27          16    0.508409            village                    Collioure
# 28          16    0.589167               town                  Carcassonne
# 29          16    0.515639            village          Tarascon-sur-Ariège
# 30          16    0.668214               city                     Toulouse
# 31          16    0.554248               town                    Montauban
# 32          16    0.579612               town                     Biarritz
# 33          16    0.602780               town                      Bayonne
# 34          16    0.601484               city                  La Rochelle
#
#                                          display_name  \
# 0   Mont Saint-Michel, Le Mont-Saint-Michel, Avran...
# 1   Saint-Malo, Ille-et-Vilaine, Bretagne, France ...
# 2   Bayeux, Calvados, Normandie, France métropolit...
# 3   Le Havre, Seine-Maritime, Normandie, France mé...
# 4   Rouen, Seine-Maritime, Normandie, France métro...
# 5   Paris, Île-de-France, France métropolitaine, F...
# 6   Amiens, Somme, Hauts-de-France, France métropo...
# 7   Lille, Nord, Hauts-de-France, France métropoli...
# 8   Strasbourg, Bas-Rhin, Grand Est, France métrop...
# 9   Château du Haut-Kœnigsbourg, Orschwiller, Séle...
# 10  Colmar, Colmar-Ribeauvillé, Haut-Rhin, Grand E...
# 11  Eguisheim, Colmar-Ribeauvillé, Haut-Rhin, Gran...
# 12  Besançon, Doubs, Bourgogne-Franche-Comté, Fran...
# 13  Dijon, Côte-d'Or, Bourgogne-Franche-Comté, Fra...
# 14  Annecy, Haute-Savoie, Auvergne-Rhône-Alpes, Fr...
# 15  Grenoble, Isère, Auvergne-Rhône-Alpes, France ...
# 16  Lyon, Métropole de Lyon, Rhône, Auvergne-Rhône...
# 17  Gorges du Verdon, La Palud-sur-Verdon, Castell...
# 18  Bormes-les-Mimosas, Toulon, Var, Provence-Alpe...
# 19  Cassis, Marseille, Bouches-du-Rhône, Provence-...
# 20  Marseille, Bouches-du-Rhône, Provence-Alpes-Cô...
# 21  Aix-en-Provence, Bouches-du-Rhône, Provence-Al...
# 22  Avignon, Vaucluse, Provence-Alpes-Côte d'Azur,...
# 23  Uzès, Nîmes, Gard, Occitanie, France métropoli...
# 24  Nîmes, Gard, Occitanie, France métropolitaine,...
# 25  Aigues-Mortes, Nîmes, Gard, Occitanie, France ...
# 26  Saintes-Maries-de-la-Mer, Arles, Bouches-du-Rh...
# 27  Collioure, Céret, Pyrénées-Orientales, Occitan...
# 28  Carcassonne, Aude, Occitanie, France métropoli...
# 29  Tarascon-sur-Ariège, Foix, Ariège, Occitanie, ...
# 30  Toulouse, Haute-Garonne, Occitanie, France mét...
# 31  Montauban, Tarn-et-Garonne, Occitanie, France ...
# 32  Biarritz, Bayonne, Pyrénées-Atlantiques, Nouve...
# 33  Bayonne, Pyrénées-Atlantiques, Nouvelle-Aquita...
# 34  La Rochelle, Charente-Maritime, Nouvelle-Aquit...
#
#                                          boundingbox
# 0   [48.6349172, 48.6370310, -1.5133292, -1.5094796]
# 1   [48.5979853, 48.6949736, -2.0765246, -1.9367259]
# 2   [49.2608124, 49.2934736, -0.7275671, -0.6757378]
# 3     [49.4516697, 49.5401463, 0.0667992, 0.1955556]
# 4     [49.4172001, 49.4652601, 1.0300648, 1.1521157]
# 5     [48.8155755, 48.9021560, 2.2241220, 2.4697602]
# 6     [49.8468370, 49.9505487, 2.2235574, 2.3457767]
# 7     [50.6008264, 50.6612596, 2.9679677, 3.1257250]
# 8     [48.4918610, 48.6461896, 7.6881371, 7.8360646]
# 9     [48.2494726, 48.2495726, 7.3454423, 7.3455423]
# 10    [48.0407053, 48.1820620, 7.3154803, 7.4691670]
# 11    [48.0240327, 48.0515072, 7.2412792, 7.3518540]
# 12    [47.2006872, 47.3200746, 5.9409668, 6.0835059]
# 13    [47.2862467, 47.3774741, 4.9624434, 5.1020598]
# 14    [45.8280024, 45.9766928, 6.0484121, 6.2043932]
# 15    [45.1541442, 45.2140762, 5.6776059, 5.7531315]
# 16    [45.7073666, 45.8082628, 4.7718134, 4.8983774]
# 17    [43.7496062, 43.7497062, 6.3285116, 6.3286116]
# 18    [43.0864271, 43.2278201, 6.2716142, 6.4514893]
# 19    [43.1884732, 43.2487231, 5.5063193, 5.5945199]
# 20    [43.1696228, 43.3910329, 5.2286312, 5.5324758]
# 21    [43.4461058, 43.6259224, 5.2694745, 5.5063013]
# 22    [43.8873819, 43.9967419, 4.7396309, 4.9271468]
# 23    [43.9811093, 44.0765914, 4.3852299, 4.4467859]
# 24    [43.7412659, 43.9230177, 4.2356708, 4.4496605]
# 25    [43.4958113, 43.5920372, 4.0760703, 4.2442867]
# 26    [43.4062445, 43.5858463, 4.2301364, 4.6444785]
# 27    [42.4832453, 42.5341084, 3.0495074, 3.0994238]
# 28    [43.1713069, 43.2443707, 2.2615684, 2.4362676]
# 29    [42.8251052, 42.8622713, 1.5600405, 1.6270996]
# 30    [43.5326540, 43.6687080, 1.3503956, 1.5153795]
# 31    [43.9512579, 44.0922122, 1.2865419, 1.4427914]
# 32  [43.4475698, 43.4945381, -1.5773906, -1.5343915]
# 33  [43.4498733, 43.5188846, -1.5048438, -1.4172610]
# 34  [46.1331804, 46.1908971, -1.2419231, -1.1110970]

# %%
#Trim the dataframe to keep only the data of interest
city_df_trim=city_df[['place_id', 'lat', 'lon', 'name']]
city_df_trim
# Out:
#      place_id         lat                 lon                         name
# 0   276970680  48.6359541  -1.511459954959514            Mont Saint-Michel
# 1   277106181   48.649518          -2.0260409                   Saint-Malo
# 2   276101915  49.2764624          -0.7024738                       Bayeux
# 3   116797886  49.4938975           0.1079732                     Le Havre
# 4   116490697  49.4404591           1.0939658                        Rouen
# 5   114827617  48.8534951           2.3483915                        Paris
# 6   116694242  49.8941708           2.2956951                       Amiens
# 7   118533424  50.6365654           3.0635282                        Lille
# 8   381804960   48.584614           7.7507127                   Strasbourg
# 9   136411398  48.2495226           7.3454923  Château du Haut-Kœnigsbourg
# 10  136331572  48.0777517           7.3579641                       Colmar
# 11  136516441  48.0447968           7.3079618                    Eguisheim
# 12  110217040  47.2380222           6.0243622                     Besançon
# 13  111540922  47.3215806           5.0414701                        Dijon
# 14  107354879  45.8992348           6.1288847                       Annecy
# 15  108194303  45.1875602           5.7357819                     Grenoble
# 16  108560795  45.7578137           4.8320114                         Lyon
# 17  101828497  43.7496562           6.3285616             Gorges du Verdon
# 18  101877567  43.1506968           6.3419285           Bormes-les-Mimosas
# 19  102437647  43.2140359           5.5396318                       Cassis
# 20  387540349  43.2961743           5.3699525                    Marseille
# 21  102741999  43.5298424           5.4474738              Aix-en-Provence
# 22  102193665  43.9492493           4.8059012                      Avignon
# 23  106427400  44.0121279           4.4196718                         Uzès
# 24  102307633  43.8374249           4.3600687                        Nîmes
# 25  102716851  43.5661521             4.19154                Aigues-Mortes
# 26  102529062  43.4515922           4.4277202     Saintes-Maries-de-la-Mer
# 27  103975931    42.52505           3.0831554                    Collioure
# 28  104358485  43.2130358           2.3491069                  Carcassonne
# 29  103773365  42.8458016           1.6067586          Tarascon-sur-Ariège
# 30  376688237  43.6044622           1.4442469                     Toulouse
# 31  105191250  44.0175835           1.3549991                    Montauban
# 32  283462568  43.4832523          -1.5592776                     Biarritz
# 33  281543649  43.4945144          -1.4736657                      Bayonne
# 34  280762466  46.1591126          -1.1520434                  La Rochelle

# %%
#reorder columns order for readability
city_df_trim=city_df_trim[[ 'name', 'place_id', 'lat', 'lon']]
city_df_trim
# Out:
#                            name   place_id         lat                 lon
# 0             Mont Saint-Michel  276970680  48.6359541  -1.511459954959514
# 1                    Saint-Malo  277106181   48.649518          -2.0260409
# 2                        Bayeux  276101915  49.2764624          -0.7024738
# 3                      Le Havre  116797886  49.4938975           0.1079732
# 4                         Rouen  116490697  49.4404591           1.0939658
# 5                         Paris  114827617  48.8534951           2.3483915
# 6                        Amiens  116694242  49.8941708           2.2956951
# 7                         Lille  118533424  50.6365654           3.0635282
# 8                    Strasbourg  381804960   48.584614           7.7507127
# 9   Château du Haut-Kœnigsbourg  136411398  48.2495226           7.3454923
# 10                       Colmar  136331572  48.0777517           7.3579641
# 11                    Eguisheim  136516441  48.0447968           7.3079618
# 12                     Besançon  110217040  47.2380222           6.0243622
# 13                        Dijon  111540922  47.3215806           5.0414701
# 14                       Annecy  107354879  45.8992348           6.1288847
# 15                     Grenoble  108194303  45.1875602           5.7357819
# 16                         Lyon  108560795  45.7578137           4.8320114
# 17             Gorges du Verdon  101828497  43.7496562           6.3285616
# 18           Bormes-les-Mimosas  101877567  43.1506968           6.3419285
# 19                       Cassis  102437647  43.2140359           5.5396318
# 20                    Marseille  387540349  43.2961743           5.3699525
# 21              Aix-en-Provence  102741999  43.5298424           5.4474738
# 22                      Avignon  102193665  43.9492493           4.8059012
# 23                         Uzès  106427400  44.0121279           4.4196718
# 24                        Nîmes  102307633  43.8374249           4.3600687
# 25                Aigues-Mortes  102716851  43.5661521             4.19154
# 26     Saintes-Maries-de-la-Mer  102529062  43.4515922           4.4277202
# 27                    Collioure  103975931    42.52505           3.0831554
# 28                  Carcassonne  104358485  43.2130358           2.3491069
# 29          Tarascon-sur-Ariège  103773365  42.8458016           1.6067586
# 30                     Toulouse  376688237  43.6044622           1.4442469
# 31                    Montauban  105191250  44.0175835           1.3549991
# 32                     Biarritz  283462568  43.4832523          -1.5592776
# 33                      Bayonne  281543649  43.4945144          -1.4736657
# 34                  La Rochelle  280762466  46.1591126          -1.1520434

# %%
# Save the coordinates dataframe as a csv
city_df_trim.to_csv('cities_coordinates.csv')

# %% [markdown]
# # Dump

# %%
paris_json ### checked the coordinates on google and it is correct
# Out:
# [{'place_id': 83293737,
#   'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. http://osm.org/copyright',
#   'osm_type': 'relation',
#   'osm_id': 71525,
#   'lat': '48.8534951',
#   'lon': '2.3483915',
#   'class': 'boundary',
#   'type': 'administrative',
#   'place_rank': 12,
#   'importance': 0.8317101715588673,
#   'addresstype': 'city',
#   'name': 'Paris',
#   'display_name': 'Paris, Île-de-France, France métropolitaine, France',
#   'boundingbox': ['48.8155755', '48.9021560', '2.2241220', '2.4697602']}]

# %%
paris_json=paris.json()
type(paris_json)
# Out:
# list

# %%
## make a dict
paris_gps=paris_json[0]
print(type(paris_gps))
paris_gps
# Out:
# <class 'dict'>
# {'place_id': 83293737,
#  'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. http://osm.org/copyright',
#  'osm_type': 'relation',
#  'osm_id': 71525,
#  'lat': '48.8534951',
#  'lon': '2.3483915',
#  'class': 'boundary',
#  'type': 'administrative',
#  'place_rank': 12,
#  'importance': 0.8317101715588673,
#  'addresstype': 'city',
#  'name': 'Paris',
#  'display_name': 'Paris, Île-de-France, France métropolitaine, France',
#  'boundingbox': ['48.8155755', '48.9021560', '2.2241220', '2.4697602']}

# %%
paris_gps_backup=paris_gps

# %%
# creer un nouveau dictionnaire en filtrant par les categories d'interet
request_list=['place_id', 'lat', 'lon', 'name']
paris_gps_trim = dict((i, paris_gps[i]) for i in request_list)
paris_gps_trim
# Out:
# {'place_id': 83293737,
#  'lat': '48.8534951',
#  'lon': '2.3483915',
#  'name': 'Paris'}

# %%
# initiate a dataframe with dictionnary keys as columns
city_keys=paris_gps_trim.keys()  #Not sure why I need to specify the index here (is of type list and not dict so this may be why)
city_df=pd.DataFrame(columns=city_keys)
city_df
# Out:
# Empty DataFrame
# Columns: [place_id, lat, lon, name]
# Index: []

# %%
paris_df=pd.DataFrame(paris_gps_trim)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[187], line 1
# ----> 1 paris_df=pd.DataFrame(paris_gps_trim)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\pandas\core\frame.py:778, in DataFrame.__init__(self, data, index, columns, dtype, copy)
#     772     mgr = self._init_mgr(
#     773         data, axes={"index": index, "columns": columns}, dtype=dtype, copy=copy
#     774     )
#     776 elif isinstance(data, dict):
#     777     # GH#38939 de facto copy defaults to False only in non-dict cases
# --> 778     mgr = dict_to_mgr(data, index, columns, dtype=dtype, copy=copy, typ=manager)
#     779 elif isinstance(data, ma.MaskedArray):
#     780     from numpy.ma import mrecords
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\pandas\core\internals\construction.py:503, in dict_to_mgr(data, index, columns, dtype, typ, copy)
#     499     else:
#     500         # dtype check to exclude e.g. range objects, scalars
#     501         arrays = [x.copy() if hasattr(x, "dtype") else x for x in arrays]
# --> 503 return arrays_to_mgr(arrays, columns, index, dtype=dtype, typ=typ, consolidate=copy)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\pandas\core\internals\construction.py:114, in arrays_to_mgr(arrays, columns, index, dtype, verify_integrity, typ, consolidate)
#     111 if verify_integrity:
#     112     # figure out the index, if necessary
#     113     if index is None:
# --> 114         index = _extract_index(arrays)
#     115     else:
#     116         index = ensure_index(index)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\pandas\core\internals\construction.py:667, in _extract_index(data)
#     664         raise ValueError("Per-column arrays must each be 1-dimensional")
#     666 if not indexes and not raw_lengths:
# --> 667     raise ValueError("If using all scalar values, you must pass an index")
#     669 if have_series:
#     670     index = union_indexes(indexes)
#
# ValueError: If using all scalar values, you must pass an index

# %%
paris_df=pd.json_normalize(paris_gps_trim).reset_index(drop=True)
paris_df
# Out:
#    place_id         lat        lon   name
# 0  83293737  48.8534951  2.3483915  Paris

# %%
city_df.index.is_unique
# Out:
# True

# %%
paris_df = paris_df.loc[~paris_df.index.duplicated(keep='first')]

# %%
# add Paris values to the dataframe
city_df=pd.concat([city_df, paris_df], ignore_index=True)
city_df
# Out:
# ---------------------------------------------------------------------------
# InvalidIndexError                         Traceback (most recent call last)
# Cell In[186], line 2
#       1 # add Paris values to the dataframe
# ----> 2 city_df=pd.concat([city_df, paris_df])
#       3 city_df
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\pandas\core\reshape\concat.py:395, in concat(objs, axis, join, ignore_index, keys, levels, names, verify_integrity, sort, copy)
#     380     copy = False
#     382 op = _Concatenator(
#     383     objs,
#     384     axis=axis,
#    (...)
#     392     sort=sort,
#     393 )
# --> 395 return op.get_result()
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\pandas\core\reshape\concat.py:680, in _Concatenator.get_result(self)
#     678         obj_labels = obj.axes[1 - ax]
#     679         if not new_labels.equals(obj_labels):
# --> 680             indexers[ax] = obj_labels.get_indexer(new_labels)
#     682     mgrs_indexers.append((obj._mgr, indexers))
#     684 new_data = concatenate_managers(
#     685     mgrs_indexers, self.new_axes, concat_axis=self.bm_axis, copy=self.copy
#     686 )
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\pandas\core\indexes\base.py:3885, in Index.get_indexer(self, target, method, limit, tolerance)
#    3882 self._check_indexing_method(method, limit, tolerance)
#    3884 if not self._index_as_unique:
# -> 3885     raise InvalidIndexError(self._requires_unique_msg)
#    3887 if len(target) == 0:
#    3888     return np.array([], dtype=np.intp)
#
# InvalidIndexError: Reindexing only valid with uniquely valued Index objects

# %%
# add Paris values to the dataframe
city_df=pd.concat([city_df, pd.DataFrame(paris_gps_trim.values())])
city_df
# Out:
# ---------------------------------------------------------------------------
# InvalidIndexError                         Traceback (most recent call last)
# Cell In[127], line 3
#       1 # add Paris values to the dataframe
#       2 # city_df=pd.concat([city_df, pd.DataFrame(columns=paris_gps_trim.values())])
# ----> 3 city_df=pd.concat([city_df, values_df], ignore_index=True)
#       4 city_df
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\pandas\core\reshape\concat.py:395, in concat(objs, axis, join, ignore_index, keys, levels, names, verify_integrity, sort, copy)
#     380     copy = False
#     382 op = _Concatenator(
#     383     objs,
#     384     axis=axis,
#    (...)
#     392     sort=sort,
#     393 )
# --> 395 return op.get_result()
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\pandas\core\reshape\concat.py:680, in _Concatenator.get_result(self)
#     678         obj_labels = obj.axes[1 - ax]
#     679         if not new_labels.equals(obj_labels):
# --> 680             indexers[ax] = obj_labels.get_indexer(new_labels)
#     682     mgrs_indexers.append((obj._mgr, indexers))
#     684 new_data = concatenate_managers(
#     685     mgrs_indexers, self.new_axes, concat_axis=self.bm_axis, copy=self.copy
#     686 )
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\pandas\core\indexes\base.py:3885, in Index.get_indexer(self, target, method, limit, tolerance)
#    3882 self._check_indexing_method(method, limit, tolerance)
#    3884 if not self._index_as_unique:
# -> 3885     raise InvalidIndexError(self._requires_unique_msg)
#    3887 if len(target) == 0:
#    3888     return np.array([], dtype=np.intp)
#
# InvalidIndexError: Reindexing only valid with uniquely valued Index objects
